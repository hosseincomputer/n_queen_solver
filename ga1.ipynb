# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
## Iniitilising and setting up the parameters and chromosomes
population_size = 10
chromosome_size = 8
epoches = 1000
run = 1
num_random_parents = 2
population = np.zeros((population_size,chromosome_size))

# %%
import matplotlib.patches as patches
board_size = 8
# Create a new figure and axis
fig, ax = plt.subplots()
# Set the aspect ratio of the plot to equal, to maintain square shape
ax.set_aspect('equal')
# Loop through each square on the chessboard
for row in range(board_size):
    for col in range(board_size):
        # Calculate the coordinates of the square
        x = col
        y = row
        # Determine the color of the square based on its position
        color = 'white' if (row + col) % 2 == 0 else 'black'
        # Create a rectangle patch for the square
        rect = patches.Rectangle((x, y), 1, 1, linewidth=1, edgecolor='black', facecolor=color)
        # Add the rectangle to the plot
        ax.add_patch(rect)
# Set the limits of the plot to display the entire chessboard
ax.set_xlim(0, board_size)
ax.set_ylim(0, board_size)
# Remove the axis ticks and labels
ax.set_xticks([])
ax.set_yticks([])
# Show the plot
plt.show()

# %%
def fitness_curve_plot(fitnees_curve):
   fig, ax = plt.subplots()
   n = np.linspace(0,1, len(fitnees_curve))
   plt.xlabel('Epoches')
   plt.ylabel('Fitness score')
   plt.plot(n, fitnees_curve,'-o')
   plt.show()
ft = [1,2,3,4,5,6,17,18]
fitness_curve_plot(ft)

# %%
n = np.linspace(0,10,100)
n
# Out:
# array([ 0.        ,  1.11111111,  2.22222222,  3.33333333,  4.44444444,
#         5.55555556,  6.66666667,  7.77777778,  8.88888889, 10.        ])
